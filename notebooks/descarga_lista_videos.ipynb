# %%
# !pip install youtube-dl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    -------- ------------------------------- 0.4/1.9 MB 8.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 10.8 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 11.0 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 7.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.5/1.9 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 7.1 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade youtube-dl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install yt-dlp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/167.7 kB ? eta -:--:--
#      -------------------------------------- 167.7/167.7 kB 5.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.4/3.1 MB 13.2 MB/s eta 0:00:01
#    ------------ --------------------------- 1.0/3.1 MB 12.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.7/3.1 MB 12.0 MB/s eta 0:00:01
#    --------------------------------- ------ 2.6/3.1 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 14.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/125.0 kB ? eta -:--:--
#    ---------------------------------------- 125.0/125.0 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/357.3 kB ? eta -:--:--
# ...

# %%
import subprocess
import os

# %%
def download_youtube_video(url, n):
    # Asegúrate de que la carpeta videos existe
    if not os.path.exists(n):
        os.makedirs(n)

    # Define el comando yt-dlp con los argumentos necesarios
    command = [
        'yt-dlp', 
        '-f', 'best', 
        '-o', f'{n}/%(title)s.%(ext)s', 
        url
    ]
    
    try:
        # Ejecuta el comando y captura la salida y errores
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        print("Video descargado exitosamente.")
        print("Salida del comando:", result.stdout)
    except subprocess.CalledProcessError as e:
        print(f"Error al descargar el video: {e}")
        print("Error detallado:", e.stderr)

# %%
Lista_peleas = ["https://youtu.be/W4-mdA_IhlA", "https://youtu.be/d41GgTIFc9A",
                "https://youtu.be/M-Inq5r61ZY","https://youtu.be/SbVEeC-WjMU", 
#                "https://youtu.be/JzSPODCCVY4", "https://youtu.be/rId9_GLxYqE", 
#                "https://youtu.be/M2b4gS_02vs", "https://youtu.be/daUJAv59sDM", 
#                "https://youtu.be/lDYknv7g2ac", "https://youtu.be/yvu2ch3U7Fo", 
#                "https://youtu.be/KYvOC7MBuUw", "https://youtu.be/Rqn4HukOhM8", 
#                "https://youtu.be/gaOTSMB6hLQ", "https://youtu.be/OsAO_gB0Jpo", 
#                "https://youtu.be/W4IKMX-5JLk", "https://youtu.be/FSyget_Uylo", 
#                "https://youtu.be/iRRVVZjLLJQ", "https://youtu.be/Wr37cbyL7PQ", 
#                "https://youtu.be/LNfHZF5GoUg", "https://youtu.be/zKZSjHTt9lc", 
#                "https://youtu.be/8QPTsc217nI", "https://youtu.be/Jk7fEEIeiSs", 
#                "https://youtu.be/JsBppgGwVts", "https://youtu.be/vqMtLA1omaU", 
#                "https://youtu.be/WbWoT0lqVVQ", "https://youtu.be/IM4rN_JvADM", 
 #               "https://youtu.be/ZldKqGpyZNc", "https://youtu.be/aOEbVtmPSRs", 
 #               "https://youtu.be/IATUT2qzDmU", "https://youtu.be/kUruG4y9mak", 
#                "https://youtu.be/UUidytFsSc0", "https://youtu.be/IcZAE6REpFA",
#                "https://youtu.be/pDi_MeXooJY", "https://youtu.be/hmYP9UqcHjA",
 #               "https://youtu.be/kGZg07vQnng", "https://youtu.be/wye8TFj6MRY",
             "https://youtu.be/MPWM10r_1-s",
             "https://youtu.be/qs1VaA0SvZM",
             "https://youtu.be/RNiZ6AVK4_4",
             "https://youtu.be/Bp8eh2O8trk",
             "https://youtu.be/HyWd7Q4k9TU",
             "https://youtu.be/-HsTU5eq9Lw",
             "https://youtu.be/3C58Q3IhKuo",
             "https://youtu.be/IX3dMqtEK-M",
             "https://youtu.be/lQlIXLVv9HA",
             "https://youtu.be/KkEEmwgdFsY",
             "https://youtu.be/PLt0ro15SM4",
             "https://youtu.be/Kw75jtfpPLI",
             "https://youtu.be/3owZ8LD7H7A",#top hooks,
             "https://youtu.be/LDaNLBssI58",#top hooks,
             "https://youtu.be/VfFOAZ_1JXc",#top hooks,
             "https://youtu.be/nIKvWLdugwg",#top hooks,
             "https://youtu.be/8oNM1j3i5-c",#top hooks,
             "https://youtu.be/QkHlV6nRyzw",#top hooks,
             "https://youtu.be/M49Ho4AJfmc",#topupper
             "https://youtu.be/8kUD5ZecQWc",#topupper
             "https://youtu.be/UZF1e69GNTA",#topupper
             "https://youtu.be/WSNNW3aFPUo",#topupper
             "https://youtu.be/rpur8kV2Dn8",#Overhand
             "https://youtu.be/VGu7oHM8_eU",#def
             "https://youtu.be/yOPr7K_-FOY",
             "https://youtu.be/d5p4fPaAI2I",
             "https://youtu.be/7eWPwsCC3QY"#def canelo,
             "https://youtu.be/Qj-bLfsQSFQ",
             "https://youtu.be/0ZsO3PgRbDY",
             "https://youtu.be/QKD7SvVaQQo",
             "https://youtu.be/xHcTBWXhvyg",
             "https://youtu.be/Nac0qnuqGDQ",
             "https://youtu.be/pH6ffL4NUSU",
             "https://youtu.be/s2I_YOAoYIc",
             "https://youtu.be/sRPjJEuOOC0",
             "https://youtu.be/wXO5Vjsrlwc",
             "https://youtu.be/_hX87-JgTBo",
             "https://youtu.be/zdWu5L11DV4",
             "https://youtu.be/Hk_IHcaEtHg",
             "https://youtu.be/-xXUvCyUIkE",
             "https://youtu.be/a6zzBF8tGaE",
             "https://youtu.be/A35tAWjohhQ",
             "https://youtu.be/nj8vMu7yDa0",
             "https://youtu.be/ZLO0pGzgAtc",
             "https://youtu.be/F-ahc8TsDWo",
             "https://youtu.be/vVPZK09coY8",
             "https://youtu.be/9l7h0PuUlSE",
             "https://youtu.be/LzcC4UJ2_ho",
             "https://youtu.be/lOwfnzW0OlQ"]

# %%
# URL del video de YouTube que quieres descargar
for cortes in lista_cortes:
    download_youtube_video(cortes, "cortes_aislar")
# Out:
# Video descargado exitosamente.
# ...

# %%
len(lista_cortes)
# Out:
# 80

# %%
nuevos = ["https://youtu.be/KN9NGbIK2q8",
          "https://youtu.be/9PY4_-YGzOM", 
          "https://youtu.be/rpur8kV2Dn8",
         ]

# %%
for nuevo in nuevos:
    download_youtube_video(nuevo, "cortes_aislar")
# Out:
# Video descargado exitosamente.
# ...
